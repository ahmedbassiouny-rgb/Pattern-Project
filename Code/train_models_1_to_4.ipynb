# %%
import os
print(os.listdir("/kaggle/input"))
# Out:
# ['datasets']

# %%
# ── Imports ────────────────────────────────────────────────────────────────
import os
import numpy as np
from PIL import Image
from collections import Counter

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader, random_split
from torchvision import transforms, models
from torchvision.models import ResNet50_Weights, ConvNeXt_Small_Weights
from sklearn.metrics import (accuracy_score, classification_report,
                              confusion_matrix, f1_score)
import matplotlib.pyplot as plt
import seaborn as sns

# ── Config ─────────────────────────────────────────────────────────────────
BATCH_SIZE = 32
NUM_EPOCHS = 30
LR         = 0.0005

DEVICE   = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SAVE_DIR = "/kaggle/working/"
os.makedirs(SAVE_DIR, exist_ok=True)

TRAIN_DIR = "/kaggle/input/datasets/ahmedbasio/emotion-dataset/archive (1) - Copy/train"
TEST_DIR  = "/kaggle/input/datasets/ahmedbasio/emotion-dataset/archive (1) - Copy/test"

# ── Dataset ────────────────────────────────────────────────────────────────
class EmotionDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.images     = []
        self.labels     = []
        self.transform  = transform
        self.class_names = sorted(os.listdir(root_dir))

        for label, cls in enumerate(self.class_names):
            folder = os.path.join(root_dir, cls)
            if not os.path.isdir(folder):
                continue
            for img in os.listdir(folder):
                self.images.append(os.path.join(folder, img))
                self.labels.append(label)

    def __len__(self):
        return len(self.images)

    def __getitem__(self, idx):
        try:
            img = Image.open(self.images[idx]).convert("RGB")
        except:
            return self.__getitem__((idx + 1) % len(self.images))
        if self.transform:
            img = self.transform(img)
        return img, self.labels[idx]

# ── Transforms ─────────────────────────────────────────────────────────────
train_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(20),
    transforms.RandomAffine(0, translate=(0.1, 0.1)),
    transforms.ColorJitter(0.3, 0.3),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

test_transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# ── Load Data ──────────────────────────────────────────────────────────────
full_train = EmotionDataset(TRAIN_DIR, train_transform)

val_size   = int(0.2 * len(full_train))
train_size = len(full_train) - val_size

train_dataset, val_dataset = random_split(
    full_train, [train_size, val_size],
    generator=torch.Generator().manual_seed(42)
)
test_dataset = EmotionDataset(TEST_DIR, test_transform)

train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True,  num_workers=2, pin_memory=True)
val_loader   = DataLoader(val_dataset,   batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)
test_loader  = DataLoader(test_dataset,  batch_size=BATCH_SIZE, shuffle=False, num_workers=2, pin_memory=True)

num_classes = len(full_train.class_names)
class_names = full_train.class_names

# ── Class Weights ──────────────────────────────────────────────────────────
counts  = Counter(full_train.labels)
total   = sum(counts.values())
weights = [total / counts[i] for i in range(num_classes)]
weights = torch.tensor(weights).float().to(DEVICE)

# ── MixUp ──────────────────────────────────────────────────────────────────
def mixup(x, y, alpha=0.2):
    lam   = np.random.beta(alpha, alpha)
    idx   = torch.randperm(x.size(0)).to(DEVICE)
    mixed = lam * x + (1 - lam) * x[idx]
    return mixed, y, y[idx], lam

# ══════════════════════════════════════════════════════════════════════════
# Attention Modules (CBAM)
# ══════════════════════════════════════════════════════════════════════════
class ChannelAttention(nn.Module):
    def __init__(self, in_channels, reduction=16):
        super().__init__()
        self.avg_pool = nn.AdaptiveAvgPool2d(1)
        self.max_pool = nn.AdaptiveMaxPool2d(1)
        self.fc = nn.Sequential(
            nn.Linear(in_channels, in_channels // reduction),
            nn.ReLU(),
            nn.Linear(in_channels // reduction, in_channels),
        )
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg  = self.fc(self.avg_pool(x).squeeze(-1).squeeze(-1))
        max_ = self.fc(self.max_pool(x).squeeze(-1).squeeze(-1))
        return x * self.sigmoid(avg + max_).unsqueeze(-1).unsqueeze(-1)


class SpatialAttention(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv    = nn.Conv2d(2, 1, kernel_size=7, padding=3)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        avg  = torch.mean(x, dim=1, keepdim=True)
        max_, _ = torch.max(x, dim=1, keepdim=True)
        return x * self.sigmoid(self.conv(torch.cat([avg, max_], dim=1)))


class CBAM(nn.Module):
    def __init__(self, in_channels):
        super().__init__()
        self.channel = ChannelAttention(in_channels)
        self.spatial = SpatialAttention()

    def forward(self, x):
        return self.spatial(self.channel(x))


# ══════════════════════════════════════════════════════════════════════════
# Spatial Transformer Network (STN) — dynamic fc_loc build
# ══════════════════════════════════════════════════════════════════════════
class STN(nn.Module):
    def __init__(self):
        super().__init__()
        self.localization = nn.Sequential(
            nn.Conv2d(3, 8,  kernel_size=7), nn.MaxPool2d(2, stride=2), nn.ReLU(True),
            nn.Conv2d(8, 10, kernel_size=5), nn.MaxPool2d(2, stride=2), nn.ReLU(True),
        )
        self.fc_loc = None  # built dynamically on first forward pass

    def forward(self, x):
        xs = self.localization(x).view(x.size(0), -1)
        if self.fc_loc is None:
            self.fc_loc = nn.Sequential(
                nn.Linear(xs.shape[1], 256), nn.ReLU(True),
                nn.Linear(256, 6)
            ).to(x.device)
            self.fc_loc[2].weight.data.zero_()
            self.fc_loc[2].bias.data.copy_(
                torch.tensor([1, 0, 0, 0, 1, 0], dtype=torch.float)
            )
        theta = self.fc_loc(xs).view(-1, 2, 3)
        grid  = F.affine_grid(theta, x.size(), align_corners=False)
        return F.grid_sample(x, grid, align_corners=False)


# ══════════════════════════════════════════════════════════════════════════
# Model 1 — Baseline ResNet50
# ══════════════════════════════════════════════════════════════════════════
class BaselineResNet50(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        base    = models.resnet50(weights=ResNet50_Weights.DEFAULT)
        # Freeze all, unfreeze layer4 + fc
        for p in base.parameters():
            p.requires_grad = False
        for p in base.layer4.parameters():
            p.requires_grad = True
        base.fc = nn.Linear(base.fc.in_features, num_classes)
        self.model = base

    def forward(self, x):
        return self.model(x)


# ══════════════════════════════════════════════════════════════════════════
# Model 2 — ResNet50 + Label Smoothing (same arch, different loss)
# ══════════════════════════════════════════════════════════════════════════
class ResNet50LabelSmoothing(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        base = models.resnet50(weights=ResNet50_Weights.DEFAULT)
        for p in base.parameters():
            p.requires_grad = False
        for p in base.layer4.parameters():
            p.requires_grad = True
        base.fc = nn.Linear(base.fc.in_features, num_classes)
        self.model = base

    def forward(self, x):
        return self.model(x)


# ══════════════════════════════════════════════════════════════════════════
# Model 3 — ResNet50 + CBAM
# ══════════════════════════════════════════════════════════════════════════
class ResNet50WithCBAM(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        base          = models.resnet50(weights=ResNet50_Weights.DEFAULT)
        self.features = nn.Sequential(*list(base.children())[:-2])
        self.cbam     = CBAM(2048)
        self.pool     = nn.AdaptiveAvgPool2d(1)
        self.fc       = nn.Linear(2048, num_classes)

    def forward(self, x):
        x = self.features(x)
        x = self.cbam(x)
        x = self.pool(x)
        return self.fc(x.flatten(1))


# ══════════════════════════════════════════════════════════════════════════
# Model 4 — ResNet50 + STN + CBAM
# ══════════════════════════════════════════════════════════════════════════
class ResNet50WithSTNAndCBAM(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.stn      = STN()
        base          = models.resnet50(weights=ResNet50_Weights.DEFAULT)
        self.features = nn.Sequential(*list(base.children())[:-2])
        self.cbam     = CBAM(2048)
        self.pool     = nn.AdaptiveAvgPool2d(1)
        self.fc       = nn.Linear(2048, num_classes)

    def forward(self, x):
        x = self.stn(x)
        x = self.features(x)
        x = self.cbam(x)
        x = self.pool(x)
        return self.fc(x.flatten(1))


# ══════════════════════════════════════════════════════════════════════════
# Model 5 — EmoNeXt (ConvNeXt-Small)
# ══════════════════════════════════════════════════════════════════════════
class EmoNeXt(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        base            = models.convnext_small(weights=ConvNeXt_Small_Weights.DEFAULT)
        self.features   = base.features
        self.avgpool    = base.avgpool
        in_features     = base.classifier[2].in_features
        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.LayerNorm(in_features),
            nn.Linear(in_features, num_classes),
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        return self.classifier(x)


# ══════════════════════════════════════════════════════════════════════════
# Train + Evaluate Function
# ══════════════════════════════════════════════════════════════════════════
def train_and_evaluate(model, name, criterion, optimizer, scheduler,
                       epochs=NUM_EPOCHS, patience=7):

    print(f"\n{'='*55}")
    print(f"🚀 Training: {name}")
    print(f"{'='*55}")

    checkpoint_path = os.path.join(SAVE_DIR, f"{name.replace(' ', '_')}_checkpoint.pth")
    best_model_path = os.path.join(SAVE_DIR, f"{name.replace(' ', '_')}_best.pth")

    start_epoch = 0
    best_acc    = 0
    counter     = 0

    # Resume if checkpoint exists
    if os.path.exists(checkpoint_path):
        ckpt = torch.load(checkpoint_path)
        model.load_state_dict(ckpt['model'])
        optimizer.load_state_dict(ckpt['optimizer'])
        start_epoch = ckpt['epoch'] + 1
        best_acc    = ckpt['best_acc']
        counter     = ckpt['counter']
        print(f"🔄 Resuming from epoch {start_epoch} | Best so far: {best_acc:.2f}%")

    for epoch in range(start_epoch, epochs):

        # ── Train ──────────────────────────────────────────────────────────
        model.train()
        total_loss = 0

        for x, y in train_loader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            optimizer.zero_grad()

            if epoch < 15:
                x, y_a, y_b, lam = mixup(x, y)
                out  = model(x)
                loss = lam * criterion(out, y_a) + (1 - lam) * criterion(out, y_b)
            else:
                out  = model(x)
                loss = criterion(out, y)

            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        scheduler.step()

        # ── Validation ─────────────────────────────────────────────────────
        model.eval()
        correct, total = 0, 0

        with torch.no_grad():
            for x, y in val_loader:
                x, y    = x.to(DEVICE), y.to(DEVICE)
                out     = model(x)
                _, pred = torch.max(out, 1)
                total   += y.size(0)
                correct += (pred == y).sum().item()

        val_acc    = 100 * correct / total
        current_lr = optimizer.param_groups[0]['lr']

        print(f"Epoch {epoch+1}/{epochs} | Loss: {total_loss:.2f} | "
              f"Val Acc: {val_acc:.2f}% | LR: {current_lr:.6f} | "
              f"Patience: {counter}/{patience}")

        # ── Save checkpoint ────────────────────────────────────────────────
        torch.save({
            'epoch':     epoch,
            'model':     model.state_dict(),
            'optimizer': optimizer.state_dict(),
            'best_acc':  best_acc,
            'counter':   counter
        }, checkpoint_path)

        # ── Best model + early stopping ────────────────────────────────────
        if val_acc > best_acc:
            best_acc = val_acc
            counter  = 0
            torch.save(model.state_dict(), best_model_path)
            print(f"  ✅ New best saved: {best_acc:.2f}%")
        else:
            counter += 1

        if counter >= patience:
            print(f"⛔ Early Stopping at epoch {epoch+1} "
                  f"(no improvement for {patience} epochs)")
            break

    # ── Test ───────────────────────────────────────────────────────────────
    model.load_state_dict(torch.load(best_model_path))
    model.eval()

    preds_list, labels_list = [], []

    with torch.no_grad():
        for x, y in test_loader:
            x    = x.to(DEVICE)
            out  = model(x)
            _, p = torch.max(out, 1)
            preds_list.extend(p.cpu().numpy())
            labels_list.extend(y.numpy())

    acc        = accuracy_score(labels_list, preds_list) * 100
    f1_w       = f1_score(labels_list, preds_list, average='weighted')
    f1_m       = f1_score(labels_list, preds_list, average='macro')

    print(f"\n🔥 {name} TEST ACCURACY : {acc:.2f}%")
    print(f"   F1 Weighted        : {f1_w:.4f}")
    print(f"   F1 Macro           : {f1_m:.4f}")

    print(f"\n📊 Classification Report — {name}:")
    print(classification_report(labels_list, preds_list, target_names=class_names))

    # ── Confusion Matrix ───────────────────────────────────────────────────
    cm = confusion_matrix(labels_list, preds_list)
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=class_names, yticklabels=class_names)
    plt.title(f'Confusion Matrix — {name}')
    plt.ylabel('True Label')
    plt.xlabel('Predicted Label')
    plt.tight_layout()
    plt.savefig(os.path.join(SAVE_DIR, f"{name.replace(' ', '_')}_confusion_matrix.png"), dpi=150)
    plt.show()

    return acc, f1_w, f1_m


# ══════════════════════════════════════════════════════════════════════════
# Run All 5 Models
# ══════════════════════════════════════════════════════════════════════════
results = {}

# ── Model 1: Baseline ResNet50 ─────────────────────────────────────────────
m1   = BaselineResNet50(num_classes).to(DEVICE)
opt1 = optim.Adam(filter(lambda p: p.requires_grad, m1.parameters()), lr=LR)
sch1 = torch.optim.lr_scheduler.CosineAnnealingLR(opt1, T_max=10)
results["1. Baseline ResNet50"] = train_and_evaluate(
    m1, "1. Baseline ResNet50",
    nn.CrossEntropyLoss(weight=weights),
    opt1, sch1
)
del m1, opt1, sch1
torch.cuda.empty_cache()

# ── Model 2: Label Smoothing ───────────────────────────────────────────────
m2   = ResNet50LabelSmoothing(num_classes).to(DEVICE)
opt2 = optim.Adam(filter(lambda p: p.requires_grad, m2.parameters()), lr=LR)
sch2 = torch.optim.lr_scheduler.CosineAnnealingLR(opt2, T_max=10)
results["2. Label Smoothing"] = train_and_evaluate(
    m2, "2. Label Smoothing",
    nn.CrossEntropyLoss(weight=weights, label_smoothing=0.1),
    opt2, sch2
)
del m2, opt2, sch2
torch.cuda.empty_cache()

# ── Model 3: ResNet50 + CBAM ───────────────────────────────────────────────
m3   = ResNet50WithCBAM(num_classes).to(DEVICE)
opt3 = optim.Adam(m3.parameters(), lr=LR, weight_decay=1e-4)
sch3 = torch.optim.lr_scheduler.CosineAnnealingLR(opt3, T_max=10)
results["3. ResNet50 + CBAM"] = train_and_evaluate(
    m3, "3. ResNet50 + CBAM",
    nn.CrossEntropyLoss(weight=weights, label_smoothing=0.1),
    opt3, sch3
)
del m3, opt3, sch3
torch.cuda.empty_cache()

# ── Model 4: ResNet50 + STN + CBAM ────────────────────────────────────────
m4   = ResNet50WithSTNAndCBAM(num_classes).to(DEVICE)
opt4 = optim.Adam(m4.parameters(), lr=LR, weight_decay=1e-4)
sch4 = torch.optim.lr_scheduler.CosineAnnealingLR(opt4, T_max=10)
results["4. ResNet50 + STN + CBAM"] = train_and_evaluate(
    m4, "4. ResNet50 + STN + CBAM",
    nn.CrossEntropyLoss(weight=weights, label_smoothing=0.1),
    opt4, sch4
)
del m4, opt4, sch4
torch.cuda.empty_cache()

# ── Model 5: EmoNeXt (ConvNeXt-Small) ─────────────────────────────────────
m5   = EmoNeXt(num_classes).to(DEVICE)
opt5 = optim.Adam(m5.parameters(), lr=0.0003, weight_decay=1e-4)
sch5 = torch.optim.lr_scheduler.CosineAnnealingLR(opt5, T_max=10)
results["5. EmoNeXt (ConvNeXt)"] = train_and_evaluate(
    m5, "5. EmoNeXt (ConvNeXt)",
    nn.CrossEntropyLoss(weight=weights, label_smoothing=0.1),
    opt5, sch5
)
del m5, opt5, sch5
torch.cuda.empty_cache()

# ══════════════════════════════════════════════════════════════════════════
# Final Comparison Table + Bar Chart
# ══════════════════════════════════════════════════════════════════════════
names   = list(results.keys())
accs    = [results[n][0]       for n in names]
f1_ws   = [results[n][1] * 100 for n in names]
f1_ms   = [results[n][2] * 100 for n in names]

# ── Print Table ────────────────────────────────────────────────────────────
print("\n" + "="*65)
print("              📊 FINAL MODEL COMPARISON")
print("="*65)
print(f"{'Model':<30} {'Accuracy':>10} {'F1 Weighted':>12} {'F1 Macro':>10}")
print("-"*65)
for n, a, fw, fm in zip(names, accs, f1_ws, f1_ms):
    print(f"{n:<30} {a:>9.2f}%  {fw:>10.2f}%  {fm:>9.2f}%")
print("="*65)
best = max(results, key=lambda n: results[n][0])
print(f"\n🏆 Best Model: {best} → {results[best][0]:.2f}%")

# ── Bar Chart ──────────────────────────────────────────────────────────────
x     = np.arange(len(names))
width = 0.25

fig, ax = plt.subplots(figsize=(14, 6))
b1 = ax.bar(x - width, accs,  width, label='Accuracy (%)',    color='steelblue')
b2 = ax.bar(x,         f1_ws, width, label='F1 Weighted (%)', color='darkorange')
b3 = ax.bar(x + width, f1_ms, width, label='F1 Macro (%)',    color='seagreen')

for bar in list(b1) + list(b2) + list(b3):
    ax.text(bar.get_x() + bar.get_width() / 2,
            bar.get_height() + 0.3,
            f'{bar.get_height():.1f}',
            ha='center', va='bottom', fontsize=7)

ax.set_xticks(x)
ax.set_xticklabels([n.split('. ', 1)[1] for n in names], rotation=15, ha='right')
ax.set_ylabel('Score (%)')
ax.set_title('Model Comparison — Accuracy & F1 Score')
ax.legend()
ax.set_ylim(0, 100)
plt.tight_layout()
plt.savefig(os.path.join(SAVE_DIR, "comparison_chart.png"), dpi=150)
plt.show()
# Out:
# =======================================================
# 🚀 Training: 1. Baseline ResNet50
# =======================================================
# Epoch 1/30 | Loss: 1173.96 | Val Acc: 48.82% | LR: 0.000488 | Patience: 0/7
#   ✅ New best saved: 48.82%
# Epoch 2/30 | Loss: 1001.48 | Val Acc: 52.29% | LR: 0.000452 | Patience: 0/7
#   ✅ New best saved: 52.29%
# Epoch 3/30 | Loss: 952.54 | Val Acc: 55.63% | LR: 0.000397 | Patience: 0/7
#   ✅ New best saved: 55.63%
# Epoch 4/30 | Loss: 917.92 | Val Acc: 57.46% | LR: 0.000327 | Patience: 0/7
#   ✅ New best saved: 57.46%
# Epoch 5/30 | Loss: 893.49 | Val Acc: 58.18% | LR: 0.000250 | Patience: 0/7
#   ✅ New best saved: 58.18%
# Epoch 6/30 | Loss: 840.79 | Val Acc: 60.15% | LR: 0.000173 | Patience: 0/7
#   ✅ New best saved: 60.15%
# Epoch 7/30 | Loss: 837.41 | Val Acc: 59.82% | LR: 0.000103 | Patience: 0/7
# Epoch 8/30 | Loss: 810.19 | Val Acc: 61.52% | LR: 0.000048 | Patience: 1/7
#   ✅ New best saved: 61.52%
# Epoch 9/30 | Loss: 788.54 | Val Acc: 61.14% | LR: 0.000012 | Patience: 0/7
# Epoch 10/30 | Loss: 757.04 | Val Acc: 61.77% | LR: 0.000000 | Patience: 1/7
#   ✅ New best saved: 61.77%
# Epoch 11/30 | Loss: 763.00 | Val Acc: 61.17% | LR: 0.000012 | Patience: 0/7
# Epoch 12/30 | Loss: 766.18 | Val Acc: 61.38% | LR: 0.000048 | Patience: 1/7
# Epoch 13/30 | Loss: 755.37 | Val Acc: 61.61% | LR: 0.000103 | Patience: 2/7
# Epoch 14/30 | Loss: 765.62 | Val Acc: 61.02% | LR: 0.000173 | Patience: 3/7
# Epoch 15/30 | Loss: 782.34 | Val Acc: 61.07% | LR: 0.000250 | Patience: 4/7
# Epoch 16/30 | Loss: 623.02 | Val Acc: 60.15% | LR: 0.000327 | Patience: 5/7
# Epoch 17/30 | Loss: 638.89 | Val Acc: 61.61% | LR: 0.000397 | Patience: 6/7
# ⛔ Early Stopping at epoch 17 (no improvement for 7 epochs)
#
# 🔥 1. Baseline ResNet50 TEST ACCURACY : 63.83%
#    F1 Weighted        : 0.6374
#    F1 Macro           : 0.5963
#
# 📊 Classification Report — 1. Baseline ResNet50:
#               precision    recall  f1-score   support
#
#        angry       0.58      0.55      0.56       959
#      disgust       0.31      0.74      0.44       111
#         fear       0.53      0.33      0.41      1024
#        happy       0.89      0.82      0.86      1774
#      neutral       0.58      0.66      0.62      1233
#          sad       0.49      0.57      0.53      1247
#     surprise       0.73      0.79      0.76       831
#
#     accuracy                           0.64      7179
#    macro avg       0.59      0.64      0.60      7179
# weighted avg       0.65      0.64      0.64      7179
# =======================================================
# 🚀 Training: 2. Label Smoothing
# =======================================================
# Epoch 1/30 | Loss: 1360.05 | Val Acc: 48.01% | LR: 0.000488 | Patience: 0/7
#   ✅ New best saved: 48.01%
# Epoch 2/30 | Loss: 1257.77 | Val Acc: 52.64% | LR: 0.000452 | Patience: 0/7
#   ✅ New best saved: 52.64%
# Epoch 3/30 | Loss: 1222.19 | Val Acc: 54.61% | LR: 0.000397 | Patience: 0/7
#   ✅ New best saved: 54.61%
# Epoch 4/30 | Loss: 1203.29 | Val Acc: 53.00% | LR: 0.000327 | Patience: 0/7
# Epoch 5/30 | Loss: 1170.74 | Val Acc: 58.18% | LR: 0.000250 | Patience: 1/7
#   ✅ New best saved: 58.18%
# Epoch 6/30 | Loss: 1149.97 | Val Acc: 57.25% | LR: 0.000173 | Patience: 0/7
# Epoch 7/30 | Loss: 1131.32 | Val Acc: 61.05% | LR: 0.000103 | Patience: 1/7
#   ✅ New best saved: 61.05%
# Epoch 8/30 | Loss: 1102.75 | Val Acc: 60.41% | LR: 0.000048 | Patience: 0/7
# Epoch 9/30 | Loss: 1093.83 | Val Acc: 61.56% | LR: 0.000012 | Patience: 1/7
#   ✅ New best saved: 61.56%
# Epoch 10/30 | Loss: 1097.64 | Val Acc: 60.44% | LR: 0.000000 | Patience: 0/7
# Epoch 11/30 | Loss: 1089.79 | Val Acc: 60.72% | LR: 0.000012 | Patience: 1/7
# Epoch 12/30 | Loss: 1082.59 | Val Acc: 61.00% | LR: 0.000048 | Patience: 2/7
# Epoch 13/30 | Loss: 1081.54 | Val Acc: 61.78% | LR: 0.000103 | Patience: 3/7
#   ✅ New best saved: 61.78%
# Epoch 14/30 | Loss: 1090.06 | Val Acc: 61.70% | LR: 0.000173 | Patience: 0/7
# Epoch 15/30 | Loss: 1090.01 | Val Acc: 60.96% | LR: 0.000250 | Patience: 1/7
# Epoch 16/30 | Loss: 992.00 | Val Acc: 61.96% | LR: 0.000327 | Patience: 2/7
#   ✅ New best saved: 61.96%
# Epoch 17/30 | Loss: 991.19 | Val Acc: 57.64% | LR: 0.000397 | Patience: 0/7
# Epoch 18/30 | Loss: 993.72 | Val Acc: 61.24% | LR: 0.000452 | Patience: 1/7
# Epoch 19/30 | Loss: 995.50 | Val Acc: 60.77% | LR: 0.000488 | Patience: 2/7
# Epoch 20/30 | Loss: 986.39 | Val Acc: 57.78% | LR: 0.000500 | Patience: 3/7
# Epoch 21/30 | Loss: 979.71 | Val Acc: 61.45% | LR: 0.000488 | Patience: 4/7
# Epoch 22/30 | Loss: 965.33 | Val Acc: 62.15% | LR: 0.000452 | Patience: 5/7
#   ✅ New best saved: 62.15%
# Epoch 23/30 | Loss: 949.15 | Val Acc: 62.11% | LR: 0.000397 | Patience: 0/7
# Epoch 24/30 | Loss: 929.41 | Val Acc: 62.22% | LR: 0.000327 | Patience: 1/7
#   ✅ New best saved: 62.22%
# Epoch 25/30 | Loss: 901.36 | Val Acc: 62.46% | LR: 0.000250 | Patience: 0/7
#   ✅ New best saved: 62.46%
# Epoch 26/30 | Loss: 875.12 | Val Acc: 64.38% | LR: 0.000173 | Patience: 0/7
#   ✅ New best saved: 64.38%
# Epoch 27/30 | Loss: 854.25 | Val Acc: 65.04% | LR: 0.000103 | Patience: 0/7
#   ✅ New best saved: 65.04%
# Epoch 28/30 | Loss: 833.89 | Val Acc: 64.55% | LR: 0.000048 | Patience: 0/7
# Epoch 29/30 | Loss: 819.40 | Val Acc: 64.73% | LR: 0.000012 | Patience: 1/7
# Epoch 30/30 | Loss: 807.93 | Val Acc: 64.76% | LR: 0.000000 | Patience: 2/7
#
# 🔥 2. Label Smoothing TEST ACCURACY : 65.29%
#    F1 Weighted        : 0.6525
#    F1 Macro           : 0.6077
#
# 📊 Classification Report — 2. Label Smoothing:
#               precision    recall  f1-score   support
#
#        angry       0.55      0.64      0.59       959
#      disgust       0.30      0.68      0.42       111
#         fear       0.58      0.40      0.47      1024
#        happy       0.89      0.85      0.87      1774
#      neutral       0.60      0.63      0.61      1233
#          sad       0.53      0.52      0.53      1247
#     surprise       0.74      0.80      0.77       831
#
#     accuracy                           0.65      7179
#    macro avg       0.60      0.65      0.61      7179
# weighted avg       0.66      0.65      0.65      7179
# =======================================================
# 🚀 Training: 3. ResNet50 + CBAM
# =======================================================
# Epoch 1/30 | Loss: 1369.28 | Val Acc: 46.02% | LR: 0.000488 | Patience: 0/7
#   ✅ New best saved: 46.02%
# Epoch 2/30 | Loss: 1276.56 | Val Acc: 50.91% | LR: 0.000452 | Patience: 0/7
#   ✅ New best saved: 50.91%
# Epoch 3/30 | Loss: 1238.96 | Val Acc: 52.80% | LR: 0.000397 | Patience: 0/7
#   ✅ New best saved: 52.80%
# Epoch 4/30 | Loss: 1221.02 | Val Acc: 55.20% | LR: 0.000327 | Patience: 0/7
#   ✅ New best saved: 55.20%
# Epoch 5/30 | Loss: 1198.77 | Val Acc: 52.33% | LR: 0.000250 | Patience: 0/7
# Epoch 6/30 | Loss: 1169.34 | Val Acc: 54.03% | LR: 0.000173 | Patience: 1/7
# Epoch 7/30 | Loss: 1143.46 | Val Acc: 59.40% | LR: 0.000103 | Patience: 2/7
#   ✅ New best saved: 59.40%
# Epoch 8/30 | Loss: 1109.98 | Val Acc: 61.10% | LR: 0.000048 | Patience: 0/7
#   ✅ New best saved: 61.10%
# Epoch 9/30 | Loss: 1085.06 | Val Acc: 63.26% | LR: 0.000012 | Patience: 0/7
#   ✅ New best saved: 63.26%
# Epoch 10/30 | Loss: 1073.47 | Val Acc: 64.38% | LR: 0.000000 | Patience: 0/7
#   ✅ New best saved: 64.38%
# Epoch 11/30 | Loss: 1065.37 | Val Acc: 64.26% | LR: 0.000012 | Patience: 0/7
# Epoch 12/30 | Loss: 1067.80 | Val Acc: 64.54% | LR: 0.000048 | Patience: 1/7
#   ✅ New best saved: 64.54%
# Epoch 13/30 | Loss: 1065.05 | Val Acc: 64.54% | LR: 0.000103 | Patience: 0/7
# Epoch 14/30 | Loss: 1080.18 | Val Acc: 63.00% | LR: 0.000173 | Patience: 1/7
# Epoch 15/30 | Loss: 1098.80 | Val Acc: 62.90% | LR: 0.000250 | Patience: 2/7
# Epoch 16/30 | Loss: 1022.00 | Val Acc: 62.93% | LR: 0.000327 | Patience: 3/7
# Epoch 17/30 | Loss: 1039.43 | Val Acc: 59.89% | LR: 0.000397 | Patience: 4/7
# Epoch 18/30 | Loss: 1048.13 | Val Acc: 59.43% | LR: 0.000452 | Patience: 5/7
# Epoch 19/30 | Loss: 1055.43 | Val Acc: 60.37% | LR: 0.000488 | Patience: 6/7
# ⛔ Early Stopping at epoch 19 (no improvement for 7 epochs)
#
# 🔥 3. ResNet50 + CBAM TEST ACCURACY : 65.93%
#    F1 Weighted        : 0.6588
#    F1 Macro           : 0.6063
#
# 📊 Classification Report — 3. ResNet50 + CBAM:
#               precision    recall  f1-score   support
#
#        angry       0.55      0.61      0.58       959
#      disgust       0.25      0.77      0.38       111
#         fear       0.55      0.34      0.42      1024
#        happy       0.90      0.86      0.88      1774
#      neutral       0.64      0.65      0.65      1233
#          sad       0.55      0.57      0.56      1247
#     surprise       0.77      0.82      0.79       831
#
#     accuracy                           0.66      7179
#    macro avg       0.60      0.66      0.61      7179
# weighted avg       0.67      0.66      0.66      7179
# =======================================================
# 🚀 Training: 4. ResNet50 + STN + CBAM
# =======================================================
# Epoch 1/30 | Loss: 1371.32 | Val Acc: 46.72% | LR: 0.000488 | Patience: 0/7
#   ✅ New best saved: 46.72%
# Epoch 2/30 | Loss: 1290.16 | Val Acc: 50.27% | LR: 0.000452 | Patience: 0/7
#   ✅ New best saved: 50.27%
# Epoch 3/30 | Loss: 1256.53 | Val Acc: 49.59% | LR: 0.000397 | Patience: 0/7
# Epoch 4/30 | Loss: 1224.13 | Val Acc: 53.81% | LR: 0.000327 | Patience: 1/7
#   ✅ New best saved: 53.81%
# Epoch 5/30 | Loss: 1200.46 | Val Acc: 56.75% | LR: 0.000250 | Patience: 0/7
#   ✅ New best saved: 56.75%
# Epoch 6/30 | Loss: 1176.21 | Val Acc: 57.74% | LR: 0.000173 | Patience: 0/7
#   ✅ New best saved: 57.74%
# Epoch 7/30 | Loss: 1142.16 | Val Acc: 59.69% | LR: 0.000103 | Patience: 0/7
#   ✅ New best saved: 59.69%
# Epoch 8/30 | Loss: 1121.09 | Val Acc: 63.14% | LR: 0.000048 | Patience: 0/7
#   ✅ New best saved: 63.14%
# Epoch 9/30 | Loss: 1100.95 | Val Acc: 63.77% | LR: 0.000012 | Patience: 0/7
#   ✅ New best saved: 63.77%
# Epoch 10/30 | Loss: 1065.11 | Val Acc: 64.03% | LR: 0.000000 | Patience: 0/7
#   ✅ New best saved: 64.03%
# Epoch 11/30 | Loss: 1070.65 | Val Acc: 63.42% | LR: 0.000012 | Patience: 0/7
# Epoch 12/30 | Loss: 1063.12 | Val Acc: 63.72% | LR: 0.000048 | Patience: 1/7
# Epoch 13/30 | Loss: 1067.92 | Val Acc: 64.22% | LR: 0.000103 | Patience: 2/7
#   ✅ New best saved: 64.22%
# Epoch 14/30 | Loss: 1087.66 | Val Acc: 63.09% | LR: 0.000173 | Patience: 0/7
# Epoch 15/30 | Loss: 1109.03 | Val Acc: 59.57% | LR: 0.000250 | Patience: 1/7
# Epoch 16/30 | Loss: 1026.15 | Val Acc: 60.96% | LR: 0.000327 | Patience: 2/7
# Epoch 17/30 | Loss: 1040.45 | Val Acc: 60.51% | LR: 0.000397 | Patience: 3/7
# Epoch 18/30 | Loss: 1055.19 | Val Acc: 59.97% | LR: 0.000452 | Patience: 4/7
# Epoch 19/30 | Loss: 1062.51 | Val Acc: 60.90% | LR: 0.000488 | Patience: 5/7
# Epoch 20/30 | Loss: 1064.97 | Val Acc: 58.37% | LR: 0.000500 | Patience: 6/7
# ⛔ Early Stopping at epoch 20 (no improvement for 7 epochs)
#
# 🔥 4. ResNet50 + STN + CBAM TEST ACCURACY : 66.11%
#    F1 Weighted        : 0.6633
#    F1 Macro           : 0.6180
#
# 📊 Classification Report — 4. ResNet50 + STN + CBAM:
#               precision    recall  f1-score   support
#
#        angry       0.57      0.63      0.60       959
#      disgust       0.30      0.69      0.42       111
#         fear       0.49      0.45      0.47      1024
#        happy       0.90      0.85      0.87      1774
#      neutral       0.62      0.64      0.63      1233
#          sad       0.57      0.52      0.54      1247
#     surprise       0.79      0.80      0.79       831
#
#     accuracy                           0.66      7179
#    macro avg       0.61      0.65      0.62      7179
# weighted avg       0.67      0.66      0.66      7179
# Downloading: "https://download.pytorch.org/models/convnext_small-0c510722.pth" to /root/.cache/torch/hub/checkpoints/convnext_small-0c510722.pth
# 100%|██████████| 192M/192M [00:00<00:00, 225MB/s]
# =======================================================
# 🚀 Training: 5. EmoNeXt (ConvNeXt)
# =======================================================
# Epoch 1/30 | Loss: 1558.23 | Val Acc: 1.38% | LR: 0.000293 | Patience: 0/7
#   ✅ New best saved: 1.38%
# Epoch 2/30 | Loss: 1549.30 | Val Acc: 1.38% | LR: 0.000271 | Patience: 0/7
# Epoch 3/30 | Loss: 1519.12 | Val Acc: 8.36% | LR: 0.000238 | Patience: 1/7
#   ✅ New best saved: 8.36%
# Epoch 4/30 | Loss: 1476.02 | Val Acc: 13.85% | LR: 0.000196 | Patience: 0/7
#   ✅ New best saved: 13.85%
# Epoch 5/30 | Loss: 1431.51 | Val Acc: 33.39% | LR: 0.000150 | Patience: 0/7
#   ✅ New best saved: 33.39%
# Epoch 6/30 | Loss: 1384.84 | Val Acc: 36.63% | LR: 0.000104 | Patience: 0/7
#   ✅ New best saved: 36.63%
# Epoch 7/30 | Loss: 1350.83 | Val Acc: 37.76% | LR: 0.000062 | Patience: 0/7
#   ✅ New best saved: 37.76%
# Epoch 8/30 | Loss: 1333.27 | Val Acc: 45.06% | LR: 0.000029 | Patience: 0/7
#   ✅ New best saved: 45.06%
# Epoch 9/30 | Loss: 1312.04 | Val Acc: 40.34% | LR: 0.000007 | Patience: 0/7
# Epoch 10/30 | Loss: 1311.04 | Val Acc: 43.86% | LR: 0.000000 | Patience: 1/7
# Epoch 11/30 | Loss: 1311.86 | Val Acc: 43.15% | LR: 0.000007 | Patience: 2/7
# Epoch 12/30 | Loss: 1305.15 | Val Acc: 42.71% | LR: 0.000029 | Patience: 3/7
# Epoch 13/30 | Loss: 1308.36 | Val Acc: 45.85% | LR: 0.000062 | Patience: 4/7
#   ✅ New best saved: 45.85%
# Epoch 14/30 | Loss: 1310.79 | Val Acc: 42.14% | LR: 0.000104 | Patience: 0/7
# Epoch 15/30 | Loss: 1305.96 | Val Acc: 47.24% | LR: 0.000150 | Patience: 1/7
#   ✅ New best saved: 47.24%
# Epoch 16/30 | Loss: 1254.28 | Val Acc: 44.99% | LR: 0.000196 | Patience: 0/7
# Epoch 17/30 | Loss: 1246.32 | Val Acc: 43.22% | LR: 0.000238 | Patience: 1/7
# Epoch 18/30 | Loss: 1237.98 | Val Acc: 43.09% | LR: 0.000271 | Patience: 2/7
# Epoch 19/30 | Loss: 1224.28 | Val Acc: 47.90% | LR: 0.000293 | Patience: 3/7
#   ✅ New best saved: 47.90%
# Epoch 20/30 | Loss: 1219.26 | Val Acc: 48.28% | LR: 0.000300 | Patience: 0/7
#   ✅ New best saved: 48.28%
# Epoch 21/30 | Loss: 1202.91 | Val Acc: 50.18% | LR: 0.000293 | Patience: 0/7
#   ✅ New best saved: 50.18%
# Epoch 22/30 | Loss: 1189.94 | Val Acc: 49.90% | LR: 0.000271 | Patience: 0/7
# Epoch 23/30 | Loss: 1178.11 | Val Acc: 49.83% | LR: 0.000238 | Patience: 1/7
# Epoch 24/30 | Loss: 1154.03 | Val Acc: 55.53% | LR: 0.000196 | Patience: 2/7
#   ✅ New best saved: 55.53%
# Epoch 25/30 | Loss: 1134.56 | Val Acc: 53.89% | LR: 0.000150 | Patience: 0/7
# Epoch 26/30 | Loss: 1114.64 | Val Acc: 55.41% | LR: 0.000104 | Patience: 1/7
# Epoch 27/30 | Loss: 1092.67 | Val Acc: 57.73% | LR: 0.000062 | Patience: 2/7
#   ✅ New best saved: 57.73%
# Epoch 28/30 | Loss: 1073.89 | Val Acc: 58.56% | LR: 0.000029 | Patience: 0/7
#   ✅ New best saved: 58.56%
# Epoch 29/30 | Loss: 1059.94 | Val Acc: 58.35% | LR: 0.000007 | Patience: 0/7
